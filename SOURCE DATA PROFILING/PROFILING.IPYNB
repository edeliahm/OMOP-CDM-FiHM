# %%
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# c:\Users\edeliac\Anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
patients = pd.read_csv(r'C:\Users\edeliac\OneDrive - HM Hospitales\Escritorio\OMOP CDM\DATA PROFILING\PERSON\person.csv')

patients.head()
# Out:
#                               patient_id_anon  gender         dob
# 0  0x0000056C600DC7FA71961AAA15BF9AEED3B35507  Female  1948-03-05
# 1  0x00000B299C5458DE170A01006BAE05225702EEFC     NaN         NaN
# 2  0x00000FBC1529FDC77730467D7D74EFB9A3160032    Male  2014-07-02
# 3  0x000012A56A9B6F056FE3CD4DFA43F878B8DA7E04     NaN         NaN
# 4  0x00001E072DFB0188606564AA05A0B2EC05DF0E85     NaN  1965-07-06

# %%
patients['patient_id_anon'] = patients['patient_id_anon'].astype(str)

patients['dob'] = pd.to_datetime(patients['dob'], errors='coerce')

patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3477884 entries, 0 to 3477883
# Data columns (total 3 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   patient_id_anon  object
#  1   gender           object
#  2   dob              datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 79.6+ MB

# %%
patients = pd.read_csv(r'C:\Users\edeliac\OneDrive - HM Hospitales\Escritorio\OMOP CDM\DATA PROFILING\PERSON\person.csv')

patients_profile = ProfileReport(patients, 
                                 title='Patient Table')

patients_profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-07-01 10:58:18.811567&quot;&gt;&lt;title&gt;Patient Table&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
patients_profile.to_file("patients_profile.html")
# Out:
# C:\Users\edeliac\AppData\Roaming\Python\Python39\site-packages\ydata_profiling\profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
